# %%
import yfinance as yf

# %%
ibov = yf.download('^BVSP')
ibov
# Out:
# [*********************100%***********************]  1 of 1 completed
#                      Open           High            Low          Close  \
# Date
# 1993-04-27      24.799999      25.400000      24.500000      24.500000
# 1993-04-28      24.500000      24.600000      23.700001      24.299999
# 1993-04-29      24.299999      24.799999      23.700001      23.700001
# 1993-04-30      23.700001      24.200001      23.700001      24.100000
# 1993-05-03      24.100000      24.400000      23.799999      24.100000
# ...                   ...            ...            ...            ...
# 2023-08-31  117537.000000  117637.000000  115742.000000  115742.000000
# 2023-09-01  115744.000000  117991.000000  115744.000000  117893.000000
# 2023-09-04  117893.000000  118576.000000  117590.000000  117777.000000
# 2023-09-05  117776.000000  117957.000000  116637.000000  117331.000000
# 2023-09-06  117331.000000  117971.000000  115984.000000  115985.000000
#
#                 Adj Close    Volume
# ...

# %%
ibov['Close'].plot(figsize=(22,8));

# %%
ibov['Variacao'] = ibov['Close'].pct_change().map(('{:.2%}').format)
ibov
# Out:
#                      Open           High            Low          Close  \
# Date
# 1993-04-27      24.799999      25.400000      24.500000      24.500000
# 1993-04-28      24.500000      24.600000      23.700001      24.299999
# 1993-04-29      24.299999      24.799999      23.700001      23.700001
# 1993-04-30      23.700001      24.200001      23.700001      24.100000
# 1993-05-03      24.100000      24.400000      23.799999      24.100000
# ...                   ...            ...            ...            ...
# 2023-08-31  117537.000000  117637.000000  115742.000000  115742.000000
# 2023-09-01  115744.000000  117991.000000  115744.000000  117893.000000
# 2023-09-04  117893.000000  118576.000000  117590.000000  117777.000000
# 2023-09-05  117776.000000  117957.000000  116637.000000  117331.000000
# 2023-09-06  117331.000000  117971.000000  115984.000000  115985.000000
#
#                 Adj Close    Volume Variacao
# Date
# 1993-04-27      24.500000         0     nan%
# ...

# %%
ibov = ibov[['Close', 'Variacao']].tail()
ibov
# Out:
#                Close Variacao
# Date
# 2023-09-06  115985.0   -1.15%
