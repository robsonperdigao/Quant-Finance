# %%
import yfinance as yf

# %%
ibov = yf.download('^BVSP')
ibov
# Out:
# [*********************100%***********************]  1 of 1 completed
#                      Open           High            Low          Close  \
# Date
# 1993-04-27      24.799999      25.400000      24.500000      24.500000
# 1993-04-28      24.500000      24.600000      23.700001      24.299999
# 1993-04-29      24.299999      24.799999      23.700001      23.700001
# 1993-04-30      23.700001      24.200001      23.700001      24.100000
# 1993-05-03      24.100000      24.400000      23.799999      24.100000
# ...                   ...            ...            ...            ...
# 2023-08-25  117025.000000  117252.000000  115397.000000  115837.000000
# 2023-08-28  115838.000000  117253.000000  115836.000000  117121.000000
# 2023-08-29  117124.000000  118493.000000  117124.000000  118404.000000
# 2023-08-30  118404.000000  118841.000000  117471.000000  117535.000000
# 2023-08-31       0.000000       0.000000       0.000000  115741.812500
#
#                 Adj Close   Volume
# ...

# %%
ibov['Close'].plot(figsize=(22,8));
