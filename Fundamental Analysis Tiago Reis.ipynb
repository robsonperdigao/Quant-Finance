# %%
import pandas as pd
import fundamentus as fd
# Out:
# 2023-10-07 21:44:59,871 [logging.log_init] INFO: LOGLEVEL=INFO

# %%
dados = fd.get_resultado()
dados
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa      pcg   pebit  \
# papel
# AALR3         9.34   -3.86  1.28  0.976  0.0000  0.438    -3.43 -652.21
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000     0.00    0.00
# ABCB4        19.75    5.53  0.82  0.000  0.0611  0.000     0.00    0.00
# ABEV3        13.19   14.55  2.44  2.512  0.0578  1.559  1026.97   12.75
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527     1.98   19.96
# ...            ...     ...   ...    ...     ...    ...      ...     ...
# WLMM4        39.58   12.71  2.21  0.650  0.0277  1.526     4.14   10.77
# WMBY3        25.39  -19.30  2.87  0.836  0.0000  0.182     1.20    8.62
# WSON33       67.00    8.07  0.98  1.067  0.0000  0.400    13.41    2.42
# YDUQ3        19.30   54.14  1.90  1.228  0.0142  0.614     6.47    7.97
# ZAMP3         6.06  -14.97  1.22  0.441  0.0000  0.415    12.52   19.63
#
# Multiples   pacl   evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# ...

# %%
dados = dados[dados['mrgliq'] > 0.2]
dados
# Out:
# Multiples  cotacao     pl   pvp     psr      dy     pa    pcg  pebit   pacl  \
# papel
# AFLT3         7.20  17.46  1.82   6.278  0.0825  1.481  12.48  16.84  28.02
# AFLU3         5.15   9.15  2.19   2.981  0.0000  1.919   9.86   8.52  12.21
# AFLU5         5.03   8.93  2.14   2.911  0.0000  1.875   9.63   8.32  11.92
# AGIN3         5.29   8.46  1.23   1.816  0.0000  0.565   1.29  10.92   3.55
# AGRO3        28.64  10.95  1.34   2.298  0.1127  0.838   4.10  10.25  76.25
# ...            ...    ...   ...     ...     ...    ...    ...    ...    ...
# TRPL4        22.30   6.20  0.84   2.686  0.0476  0.430   5.78   4.88  -1.34
# TRPN3         0.71   0.44  0.54   0.263  1.0474  0.399   0.59   0.36   0.59
# UCOP4         6.50  18.01  1.30  19.050  0.0000  0.844   5.14  22.70  -8.61
# VALE3        66.86   5.33  1.62   1.470  0.0606  0.688  31.63   3.89  -1.76
# VALE5        33.36   2.66  0.81   0.734  0.0000  0.343  15.78   1.94  -0.88
#
# ...

# %%
dados = dados[dados['pl'] < 20]
dados
# Out:
# Multiples  cotacao     pl   pvp     psr      dy     pa    pcg  pebit   pacl  \
# papel
# AFLT3         7.20  17.46  1.82   6.278  0.0825  1.481  12.48  16.84  28.02
# AFLU3         5.15   9.15  2.19   2.981  0.0000  1.919   9.86   8.52  12.21
# AFLU5         5.03   8.93  2.14   2.911  0.0000  1.875   9.63   8.32  11.92
# AGIN3         5.29   8.46  1.23   1.816  0.0000  0.565   1.29  10.92   3.55
# AGRO3        28.64  10.95  1.34   2.298  0.1127  0.838   4.10  10.25  76.25
# ...            ...    ...   ...     ...     ...    ...    ...    ...    ...
# TRPL4        22.30   6.20  0.84   2.686  0.0476  0.430   5.78   4.88  -1.34
# TRPN3         0.71   0.44  0.54   0.263  1.0474  0.399   0.59   0.36   0.59
# UCOP4         6.50  18.01  1.30  19.050  0.0000  0.844   5.14  22.70  -8.61
# VALE3        66.86   5.33  1.62   1.470  0.0606  0.688  31.63   3.89  -1.76
# VALE5        33.36   2.66  0.81   0.734  0.0000  0.343  15.78   1.94  -0.88
#
# ...

# %%
dados = dados[dados['divbpatr'] < 1]
dados
# Out:
# Multiples  cotacao     pl   pvp     psr      dy     pa    pcg  pebit   pacl  \
# papel
# AFLT3         7.20  17.46  1.82   6.278  0.0825  1.481  12.48  16.84  28.02
# AFLU3         5.15   9.15  2.19   2.981  0.0000  1.919   9.86   8.52  12.21
# AFLU5         5.03   8.93  2.14   2.911  0.0000  1.875   9.63   8.32  11.92
# AGIN3         5.29   8.46  1.23   1.816  0.0000  0.565   1.29  10.92   3.55
# AGRO3        28.64  10.95  1.34   2.298  0.1127  0.838   4.10  10.25  76.25
# ...            ...    ...   ...     ...     ...    ...    ...    ...    ...
# TRPL4        22.30   6.20  0.84   2.686  0.0476  0.430   5.78   4.88  -1.34
# TRPN3         0.71   0.44  0.54   0.263  1.0474  0.399   0.59   0.36   0.59
# UCOP4         6.50  18.01  1.30  19.050  0.0000  0.844   5.14  22.70  -8.61
# VALE3        66.86   5.33  1.62   1.470  0.0606  0.688  31.63   3.89  -1.76
# VALE5        33.36   2.66  0.81   0.734  0.0000  0.343  15.78   1.94  -0.88
#
# ...

# %%
dados = dados[dados['roe'] > 0.15]
dados
# Out:
# Multiples  cotacao     pl    pvp     psr      dy     pa     pcg   pebit  \
# papel
# AFLU3         5.15   9.15   2.19   2.981  0.0000  1.919    9.86    8.52
# AFLU5         5.03   8.93   2.14   2.911  0.0000  1.875    9.63    8.32
# ALSO3        22.19   3.97   0.87   6.858  0.0234  0.452    9.62   14.88
# AURE3        13.49   4.36   0.91   2.296  0.1112  0.409    2.78   16.18
# B3SA3        11.84  16.50   3.35   6.548  0.0355  1.460   11.12   12.59
# BLAU3        16.54   9.52   1.58   2.197  0.0362  1.187    2.75    8.05
# CEBR3        13.70   5.24   0.98   3.477  0.1089  0.701    1.63   13.88
# CEBR5        13.70   5.24   0.98   3.477  0.1089  0.701    1.63   13.88
# CEBR6        15.19   5.81   1.09   3.855  0.1080  0.777    1.80   15.39
# CIEL3         3.47   4.58   0.81   1.433  0.0835  0.098    0.71    6.06
# CMET4         3.91   8.10   5.38   3.068  0.0000  3.136    9.47    5.72
# CORR3        12.00   0.04   0.05   0.832  0.0000  0.017    0.03   -0.08
# ...

# %%
dados = dados[dados['liqc'] > 1]
dados
# Out:
# Multiples  cotacao     pl    pvp     psr      dy     pa    pcg  pebit   pacl  \
# papel
# AFLU3         5.15   9.15   2.19   2.981  0.0000  1.919   9.86   8.52  12.21
# AFLU5         5.03   8.93   2.14   2.911  0.0000  1.875   9.63   8.32  11.92
# ALSO3        22.19   3.97   0.87   6.858  0.0234  0.452   9.62  14.88  -1.33
# AURE3        13.49   4.36   0.91   2.296  0.1112  0.409   2.78  16.18  -1.49
# B3SA3        11.84  16.50   3.35   6.548  0.0355  1.460  11.12  12.59  -6.57
# BLAU3        16.54   9.52   1.58   2.197  0.0362  1.187   2.75   8.05   3.75
# CEBR3        13.70   5.24   0.98   3.477  0.1089  0.701   1.63  13.88   1.72
# CEBR5        13.70   5.24   0.98   3.477  0.1089  0.701   1.63  13.88   1.72
# CEBR6        15.19   5.81   1.09   3.855  0.1080  0.777   1.80  15.39   1.91
# CIEL3         3.47   4.58   0.81   1.433  0.0835  0.098   0.71   6.06   2.99
# CMET4         3.91   8.10   5.38   3.068  0.0000  3.136   9.47   5.72  27.20
# ...

# %%
dados = dados[dados['mrgebit'] > 0.30]
dados
# Out:
# Multiples  cotacao     pl    pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AFLU3         5.15   9.15   2.19  2.981  0.0000  1.919   9.86   8.52  12.21
# AFLU5         5.03   8.93   2.14  2.911  0.0000  1.875   9.63   8.32  11.92
# ALSO3        22.19   3.97   0.87  6.858  0.0234  0.452   9.62  14.88  -1.33
# B3SA3        11.84  16.50   3.35  6.548  0.0355  1.460  11.12  12.59  -6.57
# CMET4         3.91   8.10   5.38  3.068  0.0000  3.136   9.47   5.72  27.20
# CSTB3       150.00   0.00   0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# CSTB4       147.69   0.00   0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# HYPE3        35.18  12.85   2.02  2.756  0.0350  0.936   5.70   8.51  -4.69
# MPLU3        26.80  12.20  17.37  6.877  0.0000  2.676  50.65  10.34  66.01
# SAPR11       22.11   4.89   0.73  1.133  0.0829  0.377   8.05   2.71  -1.11
# SAPR3         4.27   4.72   0.71  1.094  0.0795  0.364   7.78   2.62  -1.08
# ...

# %%
dados['Ticker'] = dados.index.str[:4]
dados
# Out:
# C:\Users\Robson\AppData\Local\Temp\ipykernel_11736\1009329387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Ticker'] = dados.index.str[:4]
# Multiples  cotacao     pl    pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AFLU3         5.15   9.15   2.19  2.981  0.0000  1.919   9.86   8.52  12.21
# AFLU5         5.03   8.93   2.14  2.911  0.0000  1.875   9.63   8.32  11.92
# ALSO3        22.19   3.97   0.87  6.858  0.0234  0.452   9.62  14.88  -1.33
# B3SA3        11.84  16.50   3.35  6.548  0.0355  1.460  11.12  12.59  -6.57
# CMET4         3.91   8.10   5.38  3.068  0.0000  3.136   9.47   5.72  27.20
# CSTB3       150.00   0.00   0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# ...

# %%
dados = dados.drop_duplicates(subset='Ticker')
dados
# Out:
# Multiples  cotacao     pl    pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AFLU3         5.15   9.15   2.19  2.981  0.0000  1.919   9.86   8.52  12.21
# ALSO3        22.19   3.97   0.87  6.858  0.0234  0.452   9.62  14.88  -1.33
# B3SA3        11.84  16.50   3.35  6.548  0.0355  1.460  11.12  12.59  -6.57
# CMET4         3.91   8.10   5.38  3.068  0.0000  3.136   9.47   5.72  27.20
# CSTB3       150.00   0.00   0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# HYPE3        35.18  12.85   2.02  2.756  0.0350  0.936   5.70   8.51  -4.69
# MPLU3        26.80  12.20  17.37  6.877  0.0000  2.676  50.65  10.34  66.01
# SAPR11       22.11   4.89   0.73  1.133  0.0829  0.377   8.05   2.71  -1.11
# SMLS3        22.40  10.78   4.09  4.212  0.0000  1.017  18.78  10.37  -6.72
# TRPN3         0.71   0.44   0.54  0.263  1.0474  0.399   0.59   0.36   0.59
# VALE3        66.86   5.33   1.62  1.470  0.0606  0.688  31.63   3.89  -1.76
#
# ...

# %%
import quantstats as qs

# %%
qs.extend_pandas()

# %%
carteira = [i + '.SA' for i in dados.index]
carteira
# Out:
# ['AFLU3.SA',
#  'ALSO3.SA',
#  'B3SA3.SA',
#  'CMET4.SA',
#  'CSTB3.SA',
#  'HYPE3.SA',
#  'MPLU3.SA',
#  'SAPR11.SA',
#  'SMLS3.SA',
#  'TRPN3.SA',
#  'VALE3.SA']

# %%
retornos = qs.utils.download_returns(carteira, period='5y')
retornos
# Out:
# [*********************100%***********************]  11 of 11 completed
# 2023-10-07 22:12:12,522 [multi.download] ERROR:
# 6 Failed downloads:
# 2023-10-07 22:12:12,523 [multi.download] ERROR: ['CSTB3.SA', 'AFLU3.SA', 'CMET4.SA']: Exception('%ticker%: No price data found, symbol may be delisted (period=5y)')
# 2023-10-07 22:12:12,523 [multi.download] ERROR: ['TRPN3.SA', 'SMLS3.SA', 'MPLU3.SA']: Exception('%ticker%: No data found, symbol may be delisted')
#             AFLU3.SA  ALSO3.SA  B3SA3.SA  CMET4.SA  CSTB3.SA  HYPE3.SA  \
# Date
# 2018-10-08       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-10-09       NaN  0.014286  0.016194       NaN       NaN  0.021825
# 2018-10-10       NaN  0.000000 -0.011952       NaN       NaN -0.009709
# 2018-10-11       NaN -0.003286 -0.039516       NaN       NaN  0.010458
# 2018-10-15       NaN  0.028733  0.012175       NaN       NaN -0.014554
# ...              ...       ...       ...       ...       ...       ...
# ...

# %%
portfolio = qs.utils.make_portfolio(carteira, 500)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\OneDrive\ST73\Quantiq\Fundamental Analysis\Fundamental Analysis Tiago Reis.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive/ST73/Quantiq/Fundamental%20Analysis/Fundamental%20Analysis%20Tiago%20Reis.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> portfolio = qs.utils.make_portfolio(carteira, 500)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\quantstats\utils.py:405, in make_portfolio(returns, start_balance, mode, round_to)
#     403 def make_portfolio(returns, start_balance=1e5, mode="comp", round_to=None):
#     404     """Calculates compounded value of portfolio"""
# --> 405     returns = _prepare_returns(returns)
#     407     if mode.lower() in ["cumsum", "sum"]:
# ...
