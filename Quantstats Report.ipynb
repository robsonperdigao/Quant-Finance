# %%
import quantstats as qs
import pandas as pd

# %%
gold = qs.utils.download_returns('GLD')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
qs.reports.metrics(gold)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2004-11-19
# End Period          2023-10-06
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   282.38%
# CAGR﹪              5.02%
#
# Sharpe              0.49
# Prob. Sharpe Ratio  98.32%
# Sortino             0.69
# Sortino/√2          0.49
# Omega               1.09
#
# Max Drawdown        -45.56%
# Longest DD Days     3263
#
# Gain/Pain Ratio     0.09
# Gain/Pain (1M)      0.46
#
# Payoff Ratio        0.97
# Profit Factor       1.09
# Common Sense Ratio  1.11
# CPC Index           0.56
# Tail Ratio          1.01
# Outlier Win Ratio   3.77
# Outlier Loss Ratio  3.84
#
# MTD                 -1.02%
# 3M                  -4.58%
# 6M                  -9.65%
# YTD                 0.04%
# 1Y                  6.19%
# 3Y (ann.)           -1.76%
# 5Y (ann.)           5.44%
# 10Y (ann.)          2.05%
# All-time (ann.)     5.02%
#
# Avg. Drawdown       -3.56%
# Avg. Drawdown Days  87
# Recovery Factor     3.59
# Ulcer Index         0.22
# Serenity Index      0.21

# %%
qs.reports.plots(gold)

# %%
qs.reports.basic(gold)
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2004-11-19
# End Period          2023-10-06
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   282.38%
# CAGR﹪              5.02%
#
# Sharpe              0.49
# Prob. Sharpe Ratio  98.32%
# Sortino             0.69
# Sortino/√2          0.49
# Omega               1.09
#
# Max Drawdown        -45.56%
# Longest DD Days     3263
#
# Gain/Pain Ratio     0.09
# Gain/Pain (1M)      0.46
#
# Payoff Ratio        0.97
# Profit Factor       1.09
# Common Sense Ratio  1.11
# CPC Index           0.56
# Tail Ratio          1.01
# Outlier Win Ratio   3.77
# Outlier Loss Ratio  3.84
#
# MTD                 -1.02%
# 3M                  -4.58%
# 6M                  -9.65%
# YTD                 0.04%
# 1Y                  6.19%
# 3Y (ann.)           -1.76%
# 5Y (ann.)           5.44%
# 10Y (ann.)          2.05%
# All-time (ann.)     5.02%
#
# Avg. Drawdown       -3.56%
# Avg. Drawdown Days  87
# Recovery Factor     3.59
# Ulcer Index         0.22
# Serenity Index      0.21
# <h4>Strategy Visualization</h4>

# %%
qs.reports.full(gold)
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2004-11-19
# End Period                 2023-10-06
# Risk-Free Rate             0.0%
# Time in Market             100.0%
#
# Cumulative Return          282.38%
# CAGR﹪                     5.02%
#
# Sharpe                     0.49
# Prob. Sharpe Ratio         98.32%
# Smart Sharpe               0.49
# Sortino                    0.69
# Smart Sortino              0.69
# Sortino/√2                 0.49
# Smart Sortino/√2           0.49
# Omega                      1.09
#
# Max Drawdown               -45.56%
# Longest DD Days            3263
# Volatility (ann.)          17.68%
# Calmar                     0.11
# Skew                       -0.17
# Kurtosis                   6.29
#
# Expected Daily %           0.03%
# Expected Monthly %         0.59%
# Expected Yearly %          6.94%
# Kelly Criterion            4.44%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -1.8%
# Expected Shortfall (cVaR)  -1.8%
#
# Max Consecutive Wins       11
# Max Consecutive Losses     9
# Gain/Pain Ratio            0.09
# Gain/Pain (1M)             0.46
#
# Payoff Ratio               0.97
# Profit Factor              1.09
# Common Sense Ratio         1.11
# CPC Index                  0.56
# Tail Ratio                 1.01
# Outlier Win Ratio          3.77
# Outlier Loss Ratio         3.84
#
# MTD                        -1.02%
# 3M                         -4.58%
# 6M                         -9.65%
# YTD                        0.04%
# 1Y                         6.19%
# 3Y (ann.)                  -1.76%
# 5Y (ann.)                  5.44%
# 10Y (ann.)                 2.05%
# All-time (ann.)            5.02%
#
# Best Day                   11.29%
# Worst Day                  -8.78%
# Best Month                 12.79%
# Worst Month                -16.14%
# Best Year                  30.45%
# Worst Year                 -28.33%
#
# Avg. Drawdown              -3.56%
# Avg. Drawdown Days         87
# Recovery Factor            3.59
# Ulcer Index                0.22
# Serenity Index             0.21
#
# Avg. Up Month              4.51%
# Avg. Down Month            -3.16%
# Win Days %                 52.85%
# Win Month %                50.44%
# Win Quarter %              63.64%
# Win Year %                 65.0%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2011-08-23  2015-12-17  2020-07-28  3263    -45.555013        -44.287340
# 2  2008-03-18  2008-11-12  2009-09-15   547    -29.414136        -27.689825
# 3  2020-08-07  2022-09-26  2023-10-06  1156    -22.002168        -21.084122
# 4  2006-05-15  2006-06-14  2007-09-17   491    -21.794155        -20.022499
# 5  2009-12-03  2010-02-08  2010-05-10   159    -12.703473        -12.166471
# <h4>Strategy Visualization</h4>

# %%
qs.reports.html(gold, '^GSPC', title='Gold ETF Report', output='gold.html')
# Out:
# [*********************100%***********************]  1 of 1 completed
