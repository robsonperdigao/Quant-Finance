# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
from datetime import date

# %% [markdown]
# # Função para obter os dados através da API do Banco Central do Brasil

# %%
def consulta_bc(codigo_bcb, data_ini = '01-01-1900', data_fim = date.today().strftime('%d/%m/%Y')):
  url = f'http://api.bcb.gov.br/dados/serie/bcdata.sgs.{codigo_bcb}/dados?formato=json&dataInicial={data_ini}&dataFinal={data_fim}'
  df = pd.read_json(url)
  df['data'] = pd.to_datetime(df['data'], dayfirst=True)
  df.set_index('data', inplace=True)
  return df

# %% [markdown]
# # Exemplo de Consultas à API do Banco Central do Brasil

# %%
selic = consulta_bc(11)
selic.plot();

# %%
cdi = consulta_bc(12)
cdi.plot();

# %%
ipca = consulta_bc(433)
ipca.plot();

# %%
igpm = consulta_bc(189)
igpm.plot();

# %%
selic_meta = consulta_bc(432)
selic_meta.plot();

# %%
reservas_internacionais = consulta_bc(13621)
reservas_internacionais.plot();

# %%
pnad = consulta_bc(24369)
pnad.plot();
