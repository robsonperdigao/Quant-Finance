# %%
import quantstats as qs

# %%
ibov = qs.utils.download_returns('^BVSP', '6y')
sp500 = qs.utils.download_returns('^GSPC', '6y')
nasdaq = qs.utils.download_returns('^IXIC', '6y')
btc = qs.utils.download_returns('BTC-USD', '6y')
eth = qs.utils.download_returns('ETH-USD', '6y')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
carteira_ibov = {
    'BOVA11.SA': 0.95,
    'BTC-USD': 0.015,
    'ETH-USD': 0.015,
    'LTC-USD': 0.01,
    'XRP-USD': 0.01
}

# %%
portfolio_ibov = qs.utils.make_index(carteira_ibov, period='6y', rebalance=None)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
compare_ibov = qs.reports.full(portfolio_ibov, 'BOVA11.SA')
compare_ibov
# Out:
# [*********************100%***********************]  1 of 1 completed
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2017-11-13   2017-11-13
# End Period                 2023-10-16   2023-10-16
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          61.41%       77.37%
# CAGR﹪                     5.74%        6.9%
#
# Sharpe                     0.45         0.51
# Prob. Sharpe Ratio         85.61%       88.73%
# Smart Sharpe               0.38         0.44
# Sortino                    0.61         0.7
# Smart Sortino              0.52         0.6
# Sortino/√2                 0.43         0.5
# Smart Sortino/√2           0.37         0.42
# Omega                      1.1          1.1
#
# Max Drawdown               -46.93%      -44.73%
# Longest DD Days            861          861
# ...

# %%
carteira_btc5 = {
    'BOVA11.SA': 0.95,
    'BTC-USD': 0.05
}

# %%
portfolio_ibov = qs.utils.make_index(carteira_btc5, period='6y', rebalance=None)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
compare_ibov = qs.reports.full(portfolio_ibov, 'BOVA11.SA')
compare_ibov
# Out:
# [*********************100%***********************]  1 of 1 completed
# ...
